# %%
pip install pandas-profiling[notebook]
# Out:
# Requirement already satisfied: pandas-profiling[notebook] in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (3.1.0)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (0.7.4)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (0.5.1)
# Requirement already satisfied: tangled-up-in-unicode==0.1.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (0.1.0)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (2.11.3)
# Requirement already satisfied: requests>=2.24.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (2.26.0)
# Requirement already satisfied: joblib~=1.0.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (1.0.1)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (0.11.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (1.7)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (1.9.0)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (4.62.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (1.7.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (1.20.3)
# Collecting markupsafe~=2.0.1
#   Using cached MarkupSafe-2.0.1-cp37-cp37m-win_amd64.whl (14 kB)
# Requirement already satisfied: phik>=0.11.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (0.12.2)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (3.4.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (1.3.4)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (6.0)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (0.1.12)
# Requirement already satisfied: jupyter-client>=6.0.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (6.1.12)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (7.6.5)
# Requirement already satisfied: jupyter-core>=4.6.3 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas-profiling[notebook]) (4.8.1)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (21.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (2.6.3)
# Requirement already satisfied: imagehash in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (4.2.1)
# Requirement already satisfied: Pillow in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (8.4.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.0.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (7.29.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.5.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.4.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.1)
# Requirement already satisfied: argcomplete>=1.12.3 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.12.3)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.4.1)
# Requirement already satisfied: importlib-metadata<5 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (4.8.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.1.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from importlib-metadata<5->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from importlib-metadata<5->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.6.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (58.0.4)
# Requirement already satisfied: backcall in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: decorator in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.18.0)
# Requirement already satisfied: colorama in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.0.20)
# Requirement already satisfied: pygments in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.10.0)
# Requirement already satisfied: pickleshare in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from jupyter-client>=6.0.0->pandas-profiling[notebook]) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from jupyter-client>=6.0.0->pandas-profiling[notebook]) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from jupyter-core>=4.6.3->pandas-profiling[notebook]) (227)
# Requirement already satisfied: cycler>=0.10 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (3.0.4)
# Requirement already satisfied: six in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from cycler>=0.10->matplotlib>=3.2.0->pandas-profiling[notebook]) (1.16.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.18.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling[notebook]) (2021.3)
# Requirement already satisfied: wcwidth in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (2.0.4)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.4.5)
# Requirement already satisfied: prometheus-client in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.11.0)
# Requirement already satisfied: argon2-cffi in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (20.1.0)
# Requirement already satisfied: nbconvert in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.9.4)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.20)
# Requirement already satisfied: PyWavelets in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (1.1.1)
# Requirement already satisfied: defusedxml in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.5.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.1.2)
# Requirement already satisfied: testpath in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.3)
# Requirement already satisfied: bleach in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (4.0.0)
# Requirement already satisfied: async-generator in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.5.1)
# Requirement already satisfied: packaging in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (21.0)
# Requirement already satisfied: webencodings in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.5.1)
# Installing collected packages: markupsafe
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
# Successfully installed markupsafe-2.0.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cookiecutter 1.7.2 requires MarkupSafe<2.0.0, but you have markupsafe 2.0.1 which is incompatible.

# %%
pip install ruamel-yaml
# Out:
# Collecting ruamel-yaml
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.6-cp37-cp37m-win_amd64.whl (115 kB)
# Installing collected packages: ruamel.yaml.clib, ruamel-yaml
# Successfully installed ruamel-yaml-0.17.21 ruamel.yaml.clib-0.2.6
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install MarkupSafe 2.0.0
# Out:
# Requirement already satisfied: MarkupSafe in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement 2.0.0 (from versions: none)
# ERROR: No matching distribution found for 2.0.0

# %%
pip install cookiecutter
# Out:
# Requirement already satisfied: cookiecutter in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (1.7.2)
# Collecting MarkupSafe<2.0.0
# Note: you may need to restart the kernel to use updated packages.  Downloading MarkupSafe-1.1.1-cp37-cp37m-win_amd64.whl (16 kB)
# Requirement already satisfied: six>=1.10 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from cookiecutter) (1.16.0)
# Requirement already satisfied: click>=7.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from cookiecutter) (8.0.3)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.1.0 requires markupsafe~=2.0.1, but you have markupsafe 1.1.1 which is incompatible.
# Requirement already satisfied: poyo>=0.5.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from cookiecutter) (0.5.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from cookiecutter) (2.26.0)
# Requirement already satisfied: Jinja2<3.0.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from cookiecutter) (2.11.3)
# Requirement already satisfied: binaryornot>=0.4.4 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from cookiecutter) (0.4.4)
# Requirement already satisfied: jinja2-time>=0.2.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from cookiecutter) (0.2.0)
# Requirement already satisfied: python-slugify>=4.0.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from cookiecutter) (5.0.2)
# Requirement already satisfied: chardet>=3.0.2 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from binaryornot>=0.4.4->cookiecutter) (4.0.0)
# Requirement already satisfied: colorama in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from click>=7.0->cookiecutter) (0.4.4)
# Requirement already satisfied: importlib-metadata in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from click>=7.0->cookiecutter) (4.8.1)
# Requirement already satisfied: arrow in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from jinja2-time>=0.2.0->cookiecutter) (0.13.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from python-slugify>=4.0.0->cookiecutter) (1.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from requests>=2.23.0->cookiecutter) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from requests>=2.23.0->cookiecutter) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from requests>=2.23.0->cookiecutter) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from requests>=2.23.0->cookiecutter) (2.0.4)
# Requirement already satisfied: python-dateutil in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from arrow->jinja2-time>=0.2.0->cookiecutter) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from importlib-metadata->click>=7.0->cookiecutter) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (from importlib-metadata->click>=7.0->cookiecutter) (3.6.0)
# Installing collected packages: MarkupSafe
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
# Successfully installed MarkupSafe-1.1.1

# %%
pip install markupsafe
# Out:
# Requirement already satisfied: markupsafe in c:\users\tomcr\anaconda3\envs\mlenv\lib\site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Initial imports
import pandas as pd

# %%
file_path = "20_Group_4_Final_Project/Resources/modern_season_stats_clean.csv"
seasons_df = pd.read_csv(file_path)
seasons_df
# Out:
#        Year               Player Pos  Age   Tm   G  GS    MP   PER    TS%  \
# 0      1980  Kareem Abdul-Jabbar   C   32  LAL  82   0  3143  25.3  0.639
# 1      1980        Tom Abernethy  PF   25  GSW  67   0  1222  11.0  0.511
# 2      1980          Alvan Adams   C   25  PHO  75   0  2168  19.2  0.571
# 3      1980       Tiny Archibald  PG   31  BOS  80  80  2864  15.3  0.574
# 4      1980        Dennis Awtrey   C   31  CHI  26   0   560   7.4  0.524
# ...     ...                  ...  ..  ...  ...  ..  ..   ...   ...    ...
# 18922  2017          Cody Zeller  PF   24  CHO  62  58  1725  16.7  0.604
# 18923  2017         Tyler Zeller   C   27  BOS  51   5   525  13.0  0.508
# 18924  2017    Stephen Zimmerman   C   20  ORL  19   0   108   7.3  0.346
# 18925  2017          Paul Zipser  SF   22  CHI  44  18   843   6.9  0.503
# 18926  2017          Ivica Zubac   C   19  LAL  38  11   609  17.0  0.547
#
#        ...  DRB  TRB  AST  STL  BLK  TOV   PF   PTS     id  AllStar
# 0      ...  696  886  371   81  280  297  216  2034      0        1
# 1      ...  129  191   87   35   12   39  118   362      1        0
# 2      ...  451  609  322  108   55  218  237  1118      2        0
# 3      ...  138  197  671  106   10  242  218  1131      3        1
# 4      ...   86  115   40   12   15   27   66    86      4        0
# ...    ...  ...  ...  ...  ...  ...  ...  ...   ...    ...      ...
# 18922  ...  270  405   99   62   58   65  189   639  18922        0
# 18923  ...   81  124   42    7   21   20   61   178  18923        0
# 18924  ...   24   35    4    2    5    3   17    23  18924        0
# 18925  ...  110  125   36   15   16   40   78   240  18925        0
# 18926  ...  118  159   30   14   33   30   66   284  18926        0
#
# [18927 rows x 52 columns]

# %%
seasons_df.profile_report()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6036/414697883.py in <module>
# ----> 1 seasons_df.profile_report()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'profile_report'
